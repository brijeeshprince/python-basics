# %%
for item in range(1,5):
    print(item)

# %%
for item in range(5):
    print(item)

# %%
for i in range(1, 11, 2):
    print(i)

# %%
fruit = ["apple", "banana", "guava", "pine apple"]
print(fruit[1])
for item in fruit:
    print(item[0])

# %%
marks =[35,45,66,17,57]
for marks in marks:
    if marks>=35:
        print(marks,"pass")
    else:
        print(marks,"fail")

# %%
for i in range(1,10):
    if i == 5:
        break     #it breaks the loop when the given contion is satisfied
    print(i)

# %%
for i in range(1,10):
    if i == 5:
        continue      #it just skips that particular value
    print(i)

# %%
for i in range(1,10):
    if i == 5:
        break
    print(i)
else:            #In for else, else block will works only when the entire loop is completely executed
    print("Helloworld")

# %%
for i in range(1,10):
    if i == 5:
        continue
    print(i)
else:
    print("Helloworld")

# %%
for i in range(1,10):
    pass

# %%
for i in range(1,4):
    for j in range(1,4):
        print("",i,j,end=" ")
    print()

# %%
for i in range(0,2):
    name=input("Enter student name:")
    print("welcome",name)

# %%
e=int(input("Enter the number of employees:"))
s=0
for i in range(1,e+1):
    salary=int(input("Enter the salary of employee"))
    print("Employee",i,"salary :",salary)
    s=s+salary
print("total salary =",s)

# %%
total=0
n=int(input("Enter the number of students:"))
for i in range(1,n+1):
    marks=int(input("Enter the mark:"))
    print("Mark of student",i,":",marks)
    total=total+marks
print("Total Marks=",total)
print("Average Marks=",total/n)

# %%
num=int(input("Enter the number:"))
for i in range(1,11):
    mul=num*i
    print(num,"X",i,"=",mul)

# %%
e=int(input("Enter the number of employees:"))
highest=0
for i in range(1,e+1):
    salary=int(input("Enter the salary of employee"))
    if salary >highest:
        highest=salary
    print("Employee",i,"salary :",salary)
print("highest salary =",highest)

# %%
rows=int(input("Enter the number of rows:"))
num=int(input("Enter the number:"))
print("======THEATER SEAT LAYOUT======")
for row in range(0,rows):
    seat=chr(65+row)
    for number in range(1,num+1):
        print(seat,number,end="   ")
    print()

# %%
rows=int(input("Enter the number of rows:"))
print("Number of rows:",rows)
seats=int(input("Enter the number of seats per row:"))
print("Number of seats per row:",seats)
choice=""
booked_seats=[]
while choice!=5:
    print("1.  View seats")
    print("2.  Book tickets")
    print("3.  View booked seats")
    print("4.  View available seats")
    print("5.  Exit")
    choice=int(input("select your choice:"))
    print("You selected choice:",choice)
    if choice==1:
        print("\n======THEATER SEAT LAYOUT======\n")
        for row in range(0,rows):
            seat=chr(65+row)
            for number in range(1,seats+1):
                current_seat=f"{seat}{number}"
                if current_seat in booked_seats:
                    print("X",end="  ")
                else:
                    print(current_seat,end="  ")
            print()
        print("\n")
    elif choice==2:
        # book_seat=input("Enter the seat you want to book:")
        # for row in range(0,rows):
        #     seat=chr(65+row)
        #     for number in range(1,seats+1):
        #         if book_seat==seat+str(number):
        #             print("Seat booked successfully!")
        #             break
        #     else:
        #         continue
        #     break
        # else:
        #     print("Invalid seat selection.")
        
        book_seat=input("Enter the seat you want to book:").upper()
        print("You selected seat:",book_seat)
        valid_seat=False
        for row in range(0,rows):
            seat_name=chr(65+row)
            for seat in range(1,seats+1):
                current_seat=f"{seat_name}{seat}"
                if current_seat==book_seat:
                    valid_seat=True
        if not valid_seat:
            print("Invalid seat selection!")
        elif book_seat in booked_seats:
            print("Seat already booked!")
            print("try another seat")
        else:
            booked_seats.append(book_seat)
            print("Ticket booked successfully!")
        print("=======Updated Seat Layout=======")
        for row in range(0,rows):
            seat_name=chr(65+row)
            for seat in range(1,seats+1):
                current_seat=f"{seat_name}{seat}"
                if current_seat in booked_seats:
                    print("X",end="  ")
                else:
                    print(current_seat,end="  ")
            print()
    elif choice==3:
        print("=======Booked Seats=======")
        if not booked_seats:
            print("No seats booked yet.")
        else:
            for seat in booked_seats:
                print(seat,end="  ")
            print()
    elif choice==4:
        # print("=======Available Seats=======")
        # available_seats=[]
        # for row in range(0,rows):
        #     seat_name=chr(65+row)
        #     for seat in range(1,seats+1):
        #         current_seat=f"{seat_name}{seat}"
        #         if current_seat not in booked_seats:
        #             available_seats.append(current_seat)
        # if not available_seats:
        #     print("No seats available.")
        # else:
        #     for seat in available_seats:
        #         print(seat,end="  ")
        #     print()
        print("=======Summary=======")
        total_seat=rows*seats
        print("Total seat=",total_seat)
        booked=len(booked_seats)
        print("Booked_seats=",booked)
        available_seats=total_seat-booked
        print("Available_seats=",available_seats)
    else:
        print("EXIT")
